# %% [markdown]
# <a href="https://colab.research.google.com/github/nleck001/CSC221/blob/main/Assignment13_DatafileGenerator.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Assignment 13 Source File Generator
# DO NOT MODIFY

import random
def do_x_percent(n):
    chance = random.randint(0,99)
    return chance < n

_last_choice = "?"
def choose_character(include_str, exclude_str=''):
    global _last_choice
    chosen_character = random.choice(include_str)
    while chosen_character == _last_choice or chosen_character in exclude_str:
        chosen_character = random.choice(include_str)

    _last_choice = chosen_character
    return chosen_character

def rand_digit(exclude_str=''):
    return choose_character('0123456789', exclude_str)

def rand_vowel(exclude_str=''):
    return choose_character('aeiou', exclude_str)

def rand_consonant(exclude_str=''):
    return choose_character('bcdfghjklmnprstvwy', exclude_str)

def gen_first_name():
    name = rand_consonant().upper() + rand_vowel()

    for i in range(random.randint(1, 2)):
        name += rand_consonant()
        name += rand_vowel()

    return name

def gen_last_name():
    name = random.choice(['', '', '', '', '', 'de ', 'el '])
    name += rand_consonant().upper() + rand_vowel()

    for i in range(random.randint(2, 3)):
        name += rand_consonant()
        name += random.choice([rand_consonant(), rand_vowel()])
        name += rand_vowel()

    return name

def gen_default_email(first_name, last_name):
    compacted_last = last_name.replace(' ', '')
    email = first_name[0] + compacted_last[:4].lower()
    domain_choice = random.randint(1, 4)
    if domain_choice > 1:
        num = random.randint(1,7)
        email += f'{num:03d}@plattsburgh.edu'
    else:
        email += '@gmail.com'

    return email

def gen_phone_number():
    phone_number = '+' + str(random.randint(1,42))

    phone_number += ' '
    phone_number += rand_digit('0')
    for i in range(2):
       phone_number += rand_digit()

    phone_number += ' '
    for i in range(random.randint(3,4)):
       phone_number += rand_digit()

    phone_number += ' '
    for i in range(random.randint(3,4)):
       phone_number += rand_digit()

    return phone_number

def gen_pastimes():
    pastime_set = set()
    num_pastimes = random.randint(0, 4)

    for i in range(num_pastimes):
        pastime = random.choice(
            ['tennis', 'piano', 'farming', 'fishing',
             'coding', 'swimming', 'singing', 'airplanes', 'dancing',
             'reading', 'saxophone', 'cards', 'hiking', 'bicycling', 'running',
             'javelin', 'sewing', 'painting', 'poetry'])
        pastime_set.add(pastime)

    pastime_string = ""
    first_time = True
    for pastime in pastime_set:
        if first_time:
            first_time = False
        else:
            pastime_string += ', '
            first_time = False
        pastime_string += pastime

    return pastime_string

# %%
# Assignment 13 Source File Generator
# DO NOT MODIFY

class Person:
    def __init__(self):
        self.first_name = gen_first_name()
        self.last_name = gen_last_name()
        self.email = gen_default_email(self.first_name, self.last_name)
        self.phone_number = gen_phone_number()
        self.pastimes = gen_pastimes()
    def __str__(self):
        ret = f'{self.first_name} {self.last_name}, {self.email}, {self.phone_number}'
        if len(self.pastimes) > 0:
          ret += f', {self.pastimes}'
        return ret
    def as_transmitted(self):
        return str(self)
    def as_received(self):
        receive_string = self.as_transmitted()

        # These are our "typical" random transmission errors :)
        if do_x_percent(80):
            receive_string = receive_string.replace('nn', 'nnn')
        if do_x_percent(40):
            receive_string = receive_string.replace('+', '++')
        if do_x_percent(60):
            receive_string = receive_string.replace('00', '0O')
        if do_x_percent(40):
            receive_string = receive_string.replace('.com', '_dot_com')
        if do_x_percent(20):
            receive_string = receive_string.replace('plattsburgh', 'platsburgh')
        if do_x_percent(20):
            receive_string = receive_string.replace('plattsburgh', 'plattsburg')
        if do_x_percent(20):
            receive_string = receive_string.replace('plattsburgh', 'platsburg')
        if do_x_percent(20):
            receive_string = receive_string.replace('plattsburgh', 'plattsberg')
        if do_x_percent(20):
            receive_string = receive_string.replace(' ', '_')

        return receive_string

# Example People and how they are garbled
random.seed(1)
people = [Person() for x in range(20)]
for person in people:
    print(person)
    print(person.as_received())
# Out:
# Gula Tojfubtufnu, Gtojf@gmail.com, +25 360 783 7406, reading, fishing, swimming
# Gula Tojfubtufnu, Gtojf@gmail.com, ++25 360 783 7406, reading, fishing, swimming
# Nuwemi Vuceohuatwu, Nvuce003@plattsburgh.edu, +32 704 2830 836, cards, poetry, running
# Nuwemi_Vuceohuatwu,_Nvuce0O3@plattsburg.edu,_++32_704_2830_836,_cards,_poetry,_runnning
# Luru el Gusouyuo, Lelgu004@plattsburgh.edu, +23 895 9032 184
# Luru el Gusouyuo, Lelgu004@platsburgh.edu, +23 895 9032 184
# Data el Lefiahlimio, Delle@gmail.com, +2 465 3414 960, tennis
# Data_el_Lefiahlimio,_Delle@gmail_dot_com,_+2_465_3414_960,_tennnis
# Reho de Wowtonae, Rdewo001@plattsburgh.edu, +20 142 9420 939, sewing, swimming, piano
# Reho_de_Wowtonae,_Rdewo0O1@platsburg.edu,_+20_142_9420_939,_sewing,_swimming,_piano
# Refesu Vamwirmenie, Rvamw006@plattsburgh.edu, +7 685 8310 283, sewing, saxophone
# Refesu Vamwirmenie, Rvamw006@platsburg.edu, ++7 685 8310 283, sewing, saxophone
# Liname el Vencegau, Lelve005@plattsburgh.edu, +6 454 741 409
# Liname el Vencegau, Lelve0O5@plattsburgh.edu, +6 454 741 409
# Doce Sethasui, Dseth003@plattsburgh.edu, +7 350 495 6561
# Doce Sethasui, Dseth003@platsburg.edu, +7 350 495 6561
# Nufiju el Yolhijkatue, Nelyo003@plattsburgh.edu, +3 525 3518 303, painting, farming, dancing
# Nufiju_el_Yolhijkatue,_Nelyo003@plattsburgh.edu,_+3_525_3518_303,_painting,_farming,_dancing
# Dabi el Poguawhimue, Delpo002@plattsburgh.edu, +35 598 246 034
# Dabi_el_Poguawhimue,_Delpo0O2@plattsburgh.edu,_+35_598_246_034
# Toyoyo Rilaubcu, Trila002@plattsburgh.edu, +17 469 2913 0285, airplanes, saxophone, running
# Toyoyo Rilaubcu, Trila0O2@platsburgh.edu, +17 469 2913 0285, airplanes, saxophone, runnning
# Vosi Ledwujiu, Vledw002@plattsburgh.edu, +30 919 2463 765, painting, swimming, sewing
# Vosi Ledwujiu, Vledw0O2@plattsburgh.edu, +30 919 2463 765, painting, swimming, sewing
# Cula Detoenea, Cdeto005@plattsburgh.edu, +35 614 3680 879
# Cula Detoenea, Cdeto0O5@platsburgh.edu, +35 614 3680 879
# Bule Meluohio, Bmelu@gmail.com, +14 963 1019 842
# Bule Meluohio, Bmelu@gmail.com, +14 963 1019 842
# Wisupu Batiuvoeybo, Wbati006@plattsburgh.edu, +20 279 580 9659, farming, javelin, reading, airplanes
# Wisupu Batiuvoeybo, Wbati006@platsburgh.edu, ++20 279 580 9659, farming, javelin, reading, airplanes
# Bori el Hapoetlu, Belha@gmail.com, +18 819 1517 282
# Bori el Hapoetlu, Belha@gmail.com, ++18 819 1517 282
# Rijuje Lawpemiu, Rlawp004@plattsburgh.edu, +36 627 9534 096, bicycling, airplanes
# Rijuje_Lawpemiu,_Rlawp0O4@plattsburgh.edu,_++36_627_9534_096,_bicycling,_airplanes
# Lehu Gutwopmajme, Lgutw003@plattsburgh.edu, +32 120 903 789, dancing, fishing, saxophone
# Lehu Gutwopmajme, Lgutw003@plattsburg.edu, ++32 120 903 789, dancing, fishing, saxophone
# Hare Tokoetiu, Htoko@gmail.com, +14 107 6943 2062, dancing, hiking, poetry, piano
# Hare Tokoetiu, Htoko@gmail_dot_com, +14 107 6943 2062, dancing, hiking, poetry, piano
# Gamacu Welfebeo, Gwelf003@plattsburgh.edu, +41 430 569 586, painting, farming, bicycling, singing
# Gamacu_Welfebeo,_Gwelf0O3@plattsburgh.edu,_++41_430_569_586,_painting,_farming,_bicycling,_singing

# %%
# Assignment 13 Source File Generator
# DO NOT MODIFY

# Creates a population of Person objects
# Writes them uncorrupted to source_file.txt
# Writes them as received to as_received[123].txt
# Most records go into only one file but some are duplicated in two files
def make_files(my_name, record_count=100):
    random.seed(hash(my_name))

    people = [Person() for x in range(record_count)]

    source_file = open('source_file.txt', 'w')
    received_file1 = open('as_received1.txt', 'w')
    received_file2 = open('as_received2.txt', 'w')
    received_file3 = open('as_received3.txt', 'w')

    all_files = [source_file, received_file1, received_file2, received_file3]

    for file in all_files:
        file.write('Name, Email, Phone, Pastimes\n')

    source_file_line_count = 0
    received_file1_line_count = 0
    received_file2_line_count = 0
    received_file3_line_count = 0
    for person in people:
        source_file.write(person.as_transmitted() + '\n')
        source_file_line_count += 1

        # These are all 3-bit numbers that have either 1 or 2 bits turned on
        #   with a bias to a single bit
        choice = random.choice([1, 2, 4, 1, 2, 4, 1, 2, 4, 1, 2, 4, 3, 5, 6])
        if choice & 1:
            received_file1.write(person.as_received() + '\n')
            received_file1_line_count += 1
        if choice & 2:
            received_file2.write(person.as_received() + '\n')
            received_file2_line_count += 1
        if choice & 4:
            received_file3.write(person.as_received() + '\n')
            received_file3_line_count += 1

    print(f'source_file written with {source_file_line_count} lines')
    print(f'received_file1 written with {received_file1_line_count} lines')
    print(f'received_file2 written with {received_file2_line_count} lines')
    print(f'received_file3 written with {received_file3_line_count} lines')

    for file in all_files:
        file.close()

# %%
# Run this to make your data files

# Put in YOUR name
# Generate 20-50 records to debug and 100000 for your final code check
make_files(my_name='Ned Lecky', record_count=20)
# Out:
# source_file written with 20 lines
# received_file1 written with 4 lines
# received_file2 written with 5 lines
# received_file3 written with 15 lines
